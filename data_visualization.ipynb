# %% [markdown]
# ## Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %%
df = pd.read_csv('language_data.csv')
df.fillna('NA', inplace=True)
df = df.values.flatten()
df = np.delete(df, np.argwhere(df=='NA'))
df = [i.strip() for i in df]
print('Size: ', len(df))

elem, count = np.unique(df, return_counts=True)
idx   = np.argsort(count)
count = np.array(count)[idx][::-1]
elem = np.array(elem)[idx][::-1]

elem = list(elem)
count = list(count)

print(np.asarray((elem, count)))
# Out:
# Size:  17565
# [['Python' 'JavaScript' 'Java' 'C++' 'SQL' 'C#' 'C' 'PHP' 'Ruby' 'Go'
#   'Swift' 'Assembly' 'Haskell' 'TypeScript' 'R' 'Rust' 'Scala'
#   'Objective-C' 'Lua' 'Matlab' 'Perl' 'CoffeeScript' 'VB.NET' 'F#'
#   'Common Lisp' 'Clojure' 'Elixir' 'Visual Basic 6' 'Erlang' 'Dart'
#   'Hack' 'Groovy' 'Julia' 'VBA' 'Smalltalk']
#  ['1926' '1743' '1678' '1648' '1194' '1181' '1028' '909' '604' '593'
#   '593' '538' '379' '335' '314' '311' '292' '235' '235' '228' '172' '157'
#   '154' '146' '123' '121' '109' '95' '94' '85' '83' '72' '72' '69' '49']]

# %%
plt.rcParams["figure.figsize"] = (12,8)

np.random.seed(500)
N = len(elem)

area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

fig, ax = plt.subplots()
graph1 = ax.scatter(elem, count, s=count, c='gbrcmyk', alpha=0.5)
plt.xlabel('Language')

ax.set_xticklabels(elem, rotation=90)
plt.title('Programming Language Demand')
plt.show()

# %%
count[elem.index('Python')]
# Out:
# 1926

# %%
plt.rcParams["figure.figsize"] = (12,8)

fig, ax = plt.subplots()
width = 0.8
ind = np.arange(len(count))
graph2 = ax.bar(ind, count, width, color='gbc')
ax.set_xticks(ind)
ax.set_xticklabels(elem, rotation=90)

for rect, label in zip(graph2, count):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, str(label), rotation='90', ha='center', va='bottom')

plt.title('Programming Language Distribution')
plt.show()
